# %%
import pandas as pd
import matplotlib.pyplot as plt
# from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer,TfidfVectorizer

# %%
df = pd.read_csv('Employee Future Prediction.csv')
df.size
# Out:
# 41877

# %%
# We don't have any repetitive or extenstion columns
#for repetitive rows
df.drop_duplicates(inplace=True)

# %%
#mising_value_c
df.dropna()
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4645    Masters         2017       Pune            2   31  Female          No
# 4647  Bachelors         2016       Pune            3   30    Male          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
#
# ...

# %%
#mising_value_d
df.fillna(df.mean(numeric_only=True), inplace=True)
df.fillna(df.median(numeric_only=True))
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4645    Masters         2017       Pune            2   31  Female          No
# 4647  Bachelors         2016       Pune            3   30    Male          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
#
# ...

# %%
#mising_value_e
df.fillna(method='ffill', inplace=True)
df.fillna(method='bfill')
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4645    Masters         2017       Pune            2   31  Female          No
# 4647  Bachelors         2016       Pune            3   30    Male          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
#
# ...

# %% [markdown]
# <ul dir =rtl>
# <p dir=rtl style="direction: rtl;text-align: right;line-height:200%;font-family:vazir;font-size:medium">
# <li>
# اگر بیشتر ستون‌های یک سری داده خالی باشد کل سطر را حذف کنیم بهتر است</li>
#   <li>
# اگر تعداد کمی از آن ستون خالی باشد و داده ‌ها نسبت به هم فاصله داشته باشند میانگین،مد و.... بهتر است</li>
#
#   <li>
# اگر تعداد کمی از آن ستون خالی باشد و داده ‌ها نسبت به هم فاصله کمی داشته باشند و همینطور عددی نباشد استفاده از نزدیک ترین داده به خانه خالی بهتر است.</li>
# <li>
# در نتیجه هر کدام برای موقعیت‌های مختلفی بهتر است.</li>

# %%
fig = plt.figure(figsize =(10, 7))
 
plt.boxplot(df.ExperienceInCurrentDomain)
 
plt.show()

# %%
fig = plt.figure(figsize =(10, 7))
 
plt.boxplot(df.JoiningYear)
 
plt.show()

# %% [markdown]
# <ul dir =rtl>
# <p dir=rtl style="direction: rtl;text-align: right;line-height:200%;font-family:vazir;font-size:medium">
# <li>
# بعد از بررسی نمودار جعبه‌ایی برای هر ستون به این نتیجه ‌می‌رسیم که فقط برای دو ستون بالا داده‌های پرتی داریم که از طریق روش دامنه بین چارکی آن‌ها را بر طرف می‌کنیم.</li>

# %%
# cols = []
# Q1 = df[cols].quantile(0.25)
# Q3 = df[cols].quantile(0.75)
# IQR = Q3 - Q1
# df = df[~((df[cols] < (Q1 - 1.5 * IQR)) |(df[cols] > (Q3 + 1.5 * IQR))).any(axis=1)]

# %% [markdown]
# <ul dir =rtl>
# <p dir=rtl style="direction: rtl;text-align: right;line-height:200%;font-family:vazir;font-size:medium">
# <li>
#  می‌بینیم که بعد از رفع داده‌های پرت و نویز دار نمودار متعادل تر می‌شود.</li>

# %%
df['Gender'].replace(['Male','Female'],[1,0], inplace=True)
df['EverBenched'].replace(['Yes','No'],[1,0], inplace=True)
df['JoiningYear'].replace(['2012','2013','2014','2015','2016','2017'],[1 ,.025 ,0.5 ,0, 0.75,0.95], inplace=True)
df['City'].replace(['Bangalore','Pune','New Delhi'],[1 ,0.5 ,0], inplace=True)

# %%
df.to_csv('Employee Future Prediction(Prepared).csv')
