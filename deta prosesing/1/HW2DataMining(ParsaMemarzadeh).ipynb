# %% [markdown]
# payam shahmohammadi -->> 9817023132

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Employee Future Prediction.csv')

# %%
df.head(10)
# Out:
#    Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0  Bachelors         2017  Bangalore            3   34    Male          No
# 1  Bachelors         2013       Pune            1   28  Female          No
# 2  Bachelors         2014  New Delhi            3   38  Female          No
# 3    Masters         2016  Bangalore            3   27    Male          No
# 4    Masters         2017       Pune            3   24    Male         Yes
# 5  Bachelors         2016  Bangalore            3   22    Male          No
# 6  Bachelors         2015  New Delhi            3   38    Male          No
# 7  Bachelors         2016  Bangalore            3   34  Female          No
# 8  Bachelors         2016       Pune            3   23    Male          No
# 9    Masters         2017  New Delhi            2   37    Male          No
#
#    ExperienceInCurrentDomain  LeaveOrNot
# 0                          0           0
# 1                          3           1
# ...

# %%
df.tail(12)
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 4641  Bachelors         2016  Bangalore            1   33  Female          No
# 4642  Bachelors         2012  Bangalore            3   36  Female          No
# 4643  Bachelors         2013  Bangalore            3   31  Female          No
# 4644  Bachelors         2015       Pune            3   32  Female         Yes
# 4645    Masters         2017       Pune            2   31  Female          No
# 4646  Bachelors         2013  Bangalore            3   25  Female          No
# 4647  Bachelors         2016       Pune            3   30    Male          No
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# ...

# %%
df.dtypes
# Out:
# Education                    object
# JoiningYear                   int64
# City                         object
# PaymentTier                   int64
# Age                           int64
# Gender                       object
# EverBenched                  object
# ExperienceInCurrentDomain     int64
# LeaveOrNot                    int64
# dtype: object

# %% [markdown]
# <ul dir =rtl>
# <li>
# خروجی تعداد سطر و ستون دیتافریم را نشان می‌دهد</li>

# %%
df.shape
# Out:
# (4653, 9)

# %%
df.sum()
# Out:
# Education                    BachelorsBachelorsBachelorsMastersMastersBache...
# JoiningYear                                                            9376088
# City                         BangalorePuneNew DelhiBangalorePuneBangaloreNe...
# PaymentTier                                                              12555
# Age                                                                     136767
# Gender                       MaleFemaleFemaleMaleMaleMaleMaleFemaleMaleMale...
# EverBenched                  NoNoNoNoYesNoNoNoNoNoNoNoYesNoNoNoNoNoNoNoNoNo...
# ExperienceInCurrentDomain                                                13520
# LeaveOrNot                                                                1600
# dtype: object

# %%
list(df)
# Out:
# ['Education',
#  'JoiningYear',
#  'City',
#  'PaymentTier',
#  'Age',
#  'Gender',
#  'EverBenched',
#  'ExperienceInCurrentDomain',
#  'LeaveOrNot']

# %% [markdown]
# <ul dir =rtl>
# <li>
# با متد <code>rename</code> میتوان اسم ستون‌ها را تغییر داد.</li>
# <li>
# اگر inplace=True بزاریم تغییرات رو روی دیتافریم انجام میده</li>

# %%
#df.rename(columns = {'x':'X'}, inplace = True)

# %%
df.sort_values('Age')
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 63    Bachelors         2014       Pune            1   22  Female          No
# 4357  Bachelors         2014  Bangalore            3   22    Male          No
# 4377  Bachelors         2013  Bangalore            3   22    Male         Yes
# 4048  Bachelors         2014  Bangalore            3   22    Male          No
# 4225  Bachelors         2016  Bangalore            3   22    Male          No
# ...         ...          ...        ...          ...  ...     ...         ...
# 3004  Bachelors         2016  Bangalore            3   41    Male          No
# 3775    Masters         2017  Bangalore            2   41    Male         Yes
# 3355  Bachelors         2016  Bangalore            3   41    Male          No
# 3173  Bachelors         2013  Bangalore            3   41    Male          No
# 3247  Bachelors         2012  Bangalore            3   41  Female          No
#
# ...

# %%
df[df["Age"] < 30]
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 1     Bachelors         2013       Pune            1   28  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# 5     Bachelors         2016  Bangalore            3   22    Male          No
# 8     Bachelors         2016       Pune            3   23    Male          No
# ...         ...          ...        ...          ...  ...     ...         ...
# 4638  Bachelors         2013  Bangalore            3   26    Male          No
# 4639  Bachelors         2017  Bangalore            3   28    Male          No
# 4646  Bachelors         2013  Bangalore            3   25  Female          No
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
#
# ...

# %%
df["Age"].describe()
# Out:
# count    4653.000000
# mean       29.393295
# std         4.826087
# min        22.000000
# 25%        26.000000
# 50%        28.000000
# 75%        32.000000
# max        41.000000
# Name: Age, dtype: float64

# %%
df.loc[(df["Age"]<=30) & (df["Age"]<=40)]
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 1     Bachelors         2013       Pune            1   28  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# 5     Bachelors         2016  Bangalore            3   22    Male          No
# 8     Bachelors         2016       Pune            3   23    Male          No
# ...         ...          ...        ...          ...  ...     ...         ...
# 4646  Bachelors         2013  Bangalore            3   25  Female          No
# 4647  Bachelors         2016       Pune            3   30    Male          No
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
#
# ...

# %%
def plus10(x):
    return x-5
plus10(df["Age"])
# df["Year"].apply(plus10, axis=1)
# Out:
# 0       44
# 1       38
# 2       48
# 3       37
# 4       34
#         ..
# 4648    36
# 4649    47
# 4650    37
# 4651    40
# 4652    43
# Name: Age, Length: 4653, dtype: int64

# %%
df[10:122]
# Out:
#      Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 10     Masters         2012  Bangalore            3   27    Male          No
# 11   Bachelors         2016       Pune            3   34    Male          No
# 12   Bachelors         2018       Pune            3   32    Male         Yes
# 13   Bachelors         2016  Bangalore            3   39    Male          No
# 14   Bachelors         2012  Bangalore            3   37    Male          No
# ..         ...          ...        ...          ...  ...     ...         ...
# 117    Masters         2013  New Delhi            3   26    Male          No
# 118  Bachelors         2017  Bangalore            3   26  Female          No
# 119  Bachelors         2017  New Delhi            2   25    Male          No
# 120  Bachelors         2012  Bangalore            1   28  Female          No
# 121        PHD         2015  New Delhi            3   26    Male          No
#
#      ExperienceInCurrentDomain  LeaveOrNot
# ...

# %%
df.groupby('Age').filter(lambda x : len(x) >= 50)
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
# ...

# %%
df.corr()
# Out:
#                            JoiningYear  PaymentTier       Age  \
# JoiningYear                   1.000000    -0.096078  0.013165
# PaymentTier                  -0.096078     1.000000  0.007631
# Age                           0.013165     0.007631  1.000000
# ExperienceInCurrentDomain    -0.036525     0.018314 -0.134643
# LeaveOrNot                    0.181705    -0.197638 -0.051126
#
#                            ExperienceInCurrentDomain  LeaveOrNot
# JoiningYear                                -0.036525    0.181705
# PaymentTier                                 0.018314   -0.197638
# Age                                        -0.134643   -0.051126
# ExperienceInCurrentDomain                   1.000000   -0.030504
# LeaveOrNot                                 -0.030504    1.000000

# %%
dfT = df.copy()

# %%
fig , ax = plt.subplots()

df.Age.plot(kind='hist')
ax.set_xlabel('Age')
ax.set_ylabel('JoiningYear')
ax.legend();

# %%
fig , ax = plt.subplots()

df.Age.plot(kind = 'kde')
ax.set_xlabel('Age')
ax.set_ylabel('JoiningYear')
ax.legend();
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\Administrator\Desktop\mw\parsa\2\HW2DataMining(ParsaMemarzadeh).ipynb Cell 23 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Administrator/Desktop/mw/parsa/2/HW2DataMining%28ParsaMemarzadeh%29.ipynb#X35sZmlsZQ%3D%3D?line=0'>1</a> fig , ax = plt.subplots()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Administrator/Desktop/mw/parsa/2/HW2DataMining%28ParsaMemarzadeh%29.ipynb#X35sZmlsZQ%3D%3D?line=2'>3</a> df.Age.plot(kind = 'kde')
#       <a href='vscode-notebook-cell:/c%3A/Users/Administrator/Desktop/mw/parsa/2/HW2DataMining%28ParsaMemarzadeh%29.ipynb#X35sZmlsZQ%3D%3D?line=3'>4</a> ax.set_xlabel('Age')
#       <a href='vscode-notebook-cell:/c%3A/Users/Administrator/Desktop/mw/parsa/2/HW2DataMining%28ParsaMemarzadeh%29.ipynb#X35sZmlsZQ%3D%3D?line=4'>5</a> ax.set_ylabel('JoiningYear')
#
# ...
